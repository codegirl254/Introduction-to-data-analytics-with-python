# %%
 def greet():                       # defining a function
    print("Hello World!!")

# %%
greet()      # calling a function
# Out:
# Hello World!!

# %%
def greet(name):
    print("Hello " + name)

# %%
greet("Sam")
# Out:
# Hello Sam

# %%
def greet(name):
    print(f"Hello, {name}")

# %%
cars()
# Out:
# volvo benz toyota nissan

# %%
def add (a,b):
    sum =a+b
    print(sum)

# %%
add(2,4)
# Out:
# 6

# %%
def substraction(x,y):
    return x-y

# %%
results = substraction(10,7)
print(results)
# Out:
# 3

# %%
def greet():
    message = "Hello, World!"
    print(message)

greet()
# print(message)  # This will cause an error because 'message' is not defined outside the function
# Out:
# Hello, World!

# %%
def add(a, b):
    result = a + b
    return result

# %%
add(23,30)
# Out:
# 53

# %%
def calculate_grade(score):
    if score >=90:
        return "A"
    elif score>=80:
        return "B"
    elif score >=70:
        return "C"
    elif score >=60:
        return "D"
    else:
        return "F"

# %%
results=calculate_grade(97)
print(f"your grade is {results}")
# Out:
# A
# your grade is None

# %%
my_list =[1,2,3,4,5,6]
print(len(my_list))
# Out:
# 6

# %%
name ="Konya"
print(len(name))
# Out:
# 5

# %%
print(sum(my_list))
# Out:
# 21

# %%
print(type(6))
# Out:
# <class 'int'>

# %%
student_name =input("Enter name")
student_age= input("Enter Age")
for student_scores in range (3):
    student_scores=int(input("Enter score"))
def average():
    if average >=90:
        return "A"
# Out:
# Enter name Konya
# Enter Age 23
# Enter score 23
# Enter score 23
# Enter score 23

# %%
def numbers():
    a= int(input("Enter number"))
    b = int(input("Enter number"))
    return a+b

# %%
diff = a-b
print(diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 diff = a-b
#       2 print(diff)
#
# NameError: name 'a' is not defined

# %%
def numbers():
    a= int(input("Enter number"))
    b = int(input("Enter number"))
    return a+b

# %%
numbers()
# Out:
# Enter number 20
# Enter number 20
# 40

# %%
diff = a-b
print(diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 diff = a-b
#       2 print(diff)
#
# NameError: name 'a' is not defined

# %%
def main():
    # Prompting the user to input two numbers
    for num in range(2):
        num1=float(input("Enter the first number: "))
    # num1 = float(input("Enter the first number: "))
    # num2 = float(input("Enter the second number: "))

    # Calculating the sum of the two numbers
    sum_of_numbers = num1 + num2
    print(f"The sum of the two numbers is: {sum_of_numbers}")

    # Calculating the absolute difference between the two numbers
    absolute_difference = abs(num1 - num2)
    print(f"The absolute difference between the two numbers is: {absolute_difference}")

    # Determining the comparison between the two numbers
    if num1 > num2:
        comparison = "greater than"
    elif num1 < num2:
        comparison = "less than"
    else:
        comparison = "equal to"
    
    print(f"The first number is {comparison} the second number.")

# Running the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the first number:  45
# Enter the first number:  34
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 28
#      26 # Running the main function
#      27 if __name__ == "__main__":
# ---> 28     main()
#
# Cell In[100], line 9, in main()
#       4     num1=float(input("Enter the first number: "))
#       5 # num1 = float(input("Enter the first number: "))
#       6 # num2 = float(input("Enter the second number: "))
#       7
#       8 # Calculating the sum of the two numbers
# ----> 9 sum_of_numbers = num1 + num2
#      10 print(f"The sum of the two numbers is: {sum_of_numbers}")
#      12 # Calculating the absolute difference between the two numbers
#
# NameError: name 'num2' is not defined

# %%
def cars():
    print("volvo","benz","toyota","nissan")

# %%
cars()
# Out:
# volvo benz toyota nissan

# %%
def greet(name):
    print("Hello" + name)
    greet("Josphine")

# %%
greet("Josphine")
# Out:
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# HelloJosphine
# ...

# %%
def greet(name):
    print(f"hello, {name}")

# %%
greet("Konya")
# Out:
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# hello, Konya
# ...

# %%
greet("Alice")
# Out:
# Hello Alice

# %%
def subtract (x,y,z):
    results =x-y-z
    return results

# %%
substract(50,10,5)
# Out:
# 35

# %%
def greet(name):
    print("Hello"name)

# %%
greet("Konya")
# Out:
# Hello Konya

# %%
def add (a,b):
    result =a + b
    return result

# %%
x=add(4,10)

# %%
x
# Out:
# 14

# %%
numbers = 1,2,3,4,5
print(sum(numbers))
# Out:
# 15

# %%
max(40,30,20)
# Out:
# 40

# %%
name ="Konya"
len(name)
# Out:
# 5

# %%
my_list =[1,2,3,4,5]
print(my_list[0])
# Out:
# 1

# %%
number = 12345
print(number[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 number = 12345
# ----> 2 print(number[0])
#
# TypeError: 'int' object is not subscriptable

# %%
grocery=["tomatoes","onions","pumpkin"]

# %%
for item in grocery:
    print(item)
    

print(grocery)
# Out:
# tomatoes
# onions
# pumpkin
# ['tomatoes', 'onions', 'pumpkin']

# %%
ind =0

grocery=["tomatoes","onions","pumpkin"]
for item in grocery:
    if item == "onions":
        grocery[ind]="kitungu"
    ind =ind + 1
    print(item , end =" ")
# Out:
# tomatoes onions pumpkin

# %%
grocery[1]="orange"

# %%
print(grocery)
# Out:
# ['tomatoes', 'orange', 'pumpkin']

# %%
grocery.append("mangoes")

# %%
print(grocery)
# Out:
# ['tomatoes', 'kitungu', 'pumpkin', 'mangoes']

# %%
grocery.pop()
print(grocery)
# Out:
# ['tomatoes', 'kitungu']

# %%
grocery.append("onions")
print(grocery)
# Out:
# ['tomatoes', 'kitungu', 'onions']

# %%
grocery.pop()
print(grocery)
# Out:
# ['tomatoes', 'kitungu']

# %%
grocery.sort()
print(grocery)
# Out:
# ['kitungu', 'tomatoes']
