# %%
import pandas as pd

# %%
filepath ="Data_Files/Data.xlsx"
df =pd.read_excel(filepath)

# %%
df
# Out:
#        name  age   department  salary
# 0     Alice   30           HR   50000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 3     David   35  Engineering   80000
# 4       Eve   29           HR   52000
# 5     Frank   27        Sales   58000
# 6     Grace   31  Engineering   70000
# 7    Hannah   23        Sales   53000
# 8       Ian   34           HR   51000
# 9      Jack   28  Engineering   62000
# 10      Eve   29           HR   52000

# %%
df.head()
# Out:
#       name  age   department  salary
# 0    Alice   30           HR   50000
# 1      Bob   24  Engineering   60000
# 2  Charlie   26        Sales   55000
# 3    David   35  Engineering   80000
# 4      Eve   29           HR   52000

# %%
df.tail(7)
# Out:
#       name  age   department  salary
# 4      Eve   29           HR   52000
# 5    Frank   27        Sales   58000
# 6    Grace   31  Engineering   70000
# 7   Hannah   23        Sales   53000
# 8      Ian   34           HR   51000
# 9     Jack   28  Engineering   62000
# 10     Eve   29           HR   52000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        11 non-null     object
#  1   age         11 non-null     int64
#  2   department  11 non-null     object
#  3   salary      11 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 484.0+ bytes

# %%
df.columns
# Out:
# Index(['name', 'age', 'department', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (11, 4)

# %%
df.describe()
# Out:
#              age        salary
# count  11.000000     11.000000
# mean   28.727273  58454.545455
# std     3.744086   9299.071312
# min    23.000000  50000.000000
# 25%    26.500000  52000.000000
# 50%    29.000000  55000.000000
# 75%    30.500000  61000.000000
# max    35.000000  80000.000000

# %%
selected = df[["age","salary"]]

# %%
selected
# Out:
#     age  salary
# 0    30   50000
# 1    24   60000
# 2    26   55000
# 3    35   80000
# 4    29   52000
# 5    27   58000
# 6    31   70000
# 7    23   53000
# 8    34   51000
# 9    28   62000
# 10   29   52000

# %%
df.iloc[3:8]
# Selecting rows we use iloc attribute
# Out:
#      name  age   department  salary
# 3   David   35  Engineering   80000
# 4     Eve   29           HR   52000
# 5   Frank   27        Sales   58000
# 6   Grace   31  Engineering   70000
# 7  Hannah   23        Sales   53000

# %%
df.head()
# Out:
#       name  age   department  salary
# 0    Alice   30           HR   50000
# 1      Bob   24  Engineering   60000
# 2  Charlie   26        Sales   55000
# 3    David   35  Engineering   80000
# 4      Eve   29           HR   52000

# %%
df.sort_values(by = "salary",ascending =False)
# sorting
# Out:
#        name  age   department  salary
# 3     David   35  Engineering   80000
# 6     Grace   31  Engineering   70000
# 9      Jack   28  Engineering   62000
# 1       Bob   24  Engineering   60000
# 5     Frank   27        Sales   58000
# 2   Charlie   26        Sales   55000
# 7    Hannah   23        Sales   53000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 8       Ian   34           HR   51000
# 0     Alice   30           HR   50000

# %%
df.sort_values(by = "age",ascending =False)
# Out:
#        name  age   department  salary
# 3     David   35  Engineering   80000
# 8       Ian   34           HR   51000
# 6     Grace   31  Engineering   70000
# 0     Alice   30           HR   50000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 9      Jack   28  Engineering   62000
# 5     Frank   27        Sales   58000
# 2   Charlie   26        Sales   55000
# 1       Bob   24  Engineering   60000
# 7    Hannah   23        Sales   53000

# %%
df[df["age"] <25]
# Out:
#      name  age   department  salary
# 1     Bob   24  Engineering   60000
# 7  Hannah   23        Sales   53000

# %%
df[df["salary"]<55000]
# Out:
#       name  age department  salary
# 0    Alice   30         HR   50000
# 4      Eve   29         HR   52000
# 7   Hannah   23      Sales   53000
# 8      Ian   34         HR   51000
# 10     Eve   29         HR   52000

# %%
df
# Out:
#        name  age   department  salary location  Kisumu      n
# 0     Alice   30           HR   50000   Kisumu  Nakuru  Narok
# 1       Bob   24  Engineering   60000   Kisumu  Nakuru  Narok
# 2   Charlie   26        Sales   55000   Kisumu  Nakuru  Narok
# 3     David   35  Engineering   80000   Kisumu  Nakuru  Narok
# 4       Eve   29           HR   52000   Kisumu  Nakuru  Narok
# 5     Frank   27        Sales   58000   Kisumu  Nakuru  Narok
# 6     Grace   31  Engineering   70000   Kisumu  Nakuru  Narok
# 7    Hannah   23        Sales   53000   Kisumu  Nakuru  Narok
# 8       Ian   34           HR   51000   Kisumu  Nakuru  Narok
# 9      Jack   28  Engineering   62000   Kisumu  Nakuru  Narok
# 10      Eve   29           HR   52000   Kisumu  Nakuru  Narok

# %%
df.drop("Kisumu",axis=1)
# Out:
#        name  age   department  salary location      n
# 0     Alice   30           HR   50000   Kisumu  Narok
# 1       Bob   24  Engineering   60000   Kisumu  Narok
# 2   Charlie   26        Sales   55000   Kisumu  Narok
# 3     David   35  Engineering   80000   Kisumu  Narok
# 4       Eve   29           HR   52000   Kisumu  Narok
# 5     Frank   27        Sales   58000   Kisumu  Narok
# 6     Grace   31  Engineering   70000   Kisumu  Narok
# 7    Hannah   23        Sales   53000   Kisumu  Narok
# 8       Ian   34           HR   51000   Kisumu  Narok
# 9      Jack   28  Engineering   62000   Kisumu  Narok
# 10      Eve   29           HR   52000   Kisumu  Narok

# %%
df.drop("n",axis=1)
# Out:
#        name  age   department  salary location  Kisumu
# 0     Alice   30           HR   50000   Kisumu  Nakuru
# 1       Bob   24  Engineering   60000   Kisumu  Nakuru
# 2   Charlie   26        Sales   55000   Kisumu  Nakuru
# 3     David   35  Engineering   80000   Kisumu  Nakuru
# 4       Eve   29           HR   52000   Kisumu  Nakuru
# 5     Frank   27        Sales   58000   Kisumu  Nakuru
# 6     Grace   31  Engineering   70000   Kisumu  Nakuru
# 7    Hannah   23        Sales   53000   Kisumu  Nakuru
# 8       Ian   34           HR   51000   Kisumu  Nakuru
# 9      Jack   28  Engineering   62000   Kisumu  Nakuru
# 10      Eve   29           HR   52000   Kisumu  Nakuru

# %%
df
# Out:
#        name  age   department  salary location  Kisumu      n
# 0     Alice   30           HR   50000   Kisumu  Nakuru  Narok
# 1       Bob   24  Engineering   60000   Kisumu  Nakuru  Narok
# 2   Charlie   26        Sales   55000   Kisumu  Nakuru  Narok
# 3     David   35  Engineering   80000   Kisumu  Nakuru  Narok
# 4       Eve   29           HR   52000   Kisumu  Nakuru  Narok
# 5     Frank   27        Sales   58000   Kisumu  Nakuru  Narok
# 6     Grace   31  Engineering   70000   Kisumu  Nakuru  Narok
# 7    Hannah   23        Sales   53000   Kisumu  Nakuru  Narok
# 8       Ian   34           HR   51000   Kisumu  Nakuru  Narok
# 9      Jack   28  Engineering   62000   Kisumu  Nakuru  Narok
# 10      Eve   29           HR   52000   Kisumu  Nakuru  Narok

# %%
df=df.drop("Kisumu",axis=1)

# %%
df
# Out:
#        name  age   department  salary location      n
# 0     Alice   30           HR   50000   Kisumu  Narok
# 1       Bob   24  Engineering   60000   Kisumu  Narok
# 2   Charlie   26        Sales   55000   Kisumu  Narok
# 3     David   35  Engineering   80000   Kisumu  Narok
# 4       Eve   29           HR   52000   Kisumu  Narok
# 5     Frank   27        Sales   58000   Kisumu  Narok
# 6     Grace   31  Engineering   70000   Kisumu  Narok
# 7    Hannah   23        Sales   53000   Kisumu  Narok
# 8       Ian   34           HR   51000   Kisumu  Narok
# 9      Jack   28  Engineering   62000   Kisumu  Narok
# 10      Eve   29           HR   52000   Kisumu  Narok

# %%
df =df.drop("n",axis=1)

# %%
df
# Out:
#        name  age   department  salary location
# 0     Alice   30           HR   50000   Kisumu
# 1       Bob   24  Engineering   60000   Kisumu
# 2   Charlie   26        Sales   55000   Kisumu
# 3     David   35  Engineering   80000   Kisumu
# 4       Eve   29           HR   52000   Kisumu
# 5     Frank   27        Sales   58000   Kisumu
# 6     Grace   31  Engineering   70000   Kisumu
# 7    Hannah   23        Sales   53000   Kisumu
# 8       Ian   34           HR   51000   Kisumu
# 9      Jack   28  Engineering   62000   Kisumu
# 10      Eve   29           HR   52000   Kisumu

# %%
df.drop([columns=="Kisummu"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 df.drop([columns=="Kisummu"])
#
# NameError: name 'columns' is not defined

# %%
df.loc[df['name'] == 'Alice', 'location'] = 'Nairobi'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.loc[df['name'] == 'Alice', 'location'] = 'Nairobi'
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#        name  age   department  salary location
# 0     Alice   30           HR   50000  Nairobi
# 1       Bob   24  Engineering   60000   Kisumu
# 2   Charlie   26        Sales   55000   Kisumu
# 3     David   35  Engineering   80000   Kisumu
# 4       Eve   29           HR   52000   Kisumu
# 5     Frank   27        Sales   58000   Kisumu
# 6     Grace   31  Engineering   70000   Kisumu
# 7    Hannah   23        Sales   53000   Kisumu
# 8       Ian   34           HR   51000   Kisumu
# 9      Jack   28  Engineering   62000   Kisumu
# 10      Eve   29           HR   52000   Kisumu

# %%
df
# Out:
#        name  age   department  salary location (False, location)
# 0     Alice   30           HR   50000  Nairobi             Narok
# 1       Bob   24  Engineering   60000   Kisumu             Narok
# 2   Charlie   26        Sales   55000   Kisumu             Narok
# 3     David   35  Engineering   80000   Kisumu             Narok
# 4       Eve   29           HR   52000   Kisumu             Narok
# 5     Frank   27        Sales   58000   Kisumu             Narok
# 6     Grace   31  Engineering   70000   Kisumu             Narok
# 7    Hannah   23        Sales   53000   Kisumu             Narok
# 8       Ian   34           HR   51000   Kisumu             Narok
# 9      Jack   28  Engineering   62000   Kisumu             Narok
# 10      Eve   29           HR   52000   Kisumu             Narok

# %%
df = df.drop(columns=[('False', 'location')])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 df = df.drop(columns=[('False', 'location')])
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df = df.drop("False" ,axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 df = df.drop("False" ,axis =1)
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df = df.drop(columns=['(False, location)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 df = df.drop(columns=['(False, location)'])
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...
